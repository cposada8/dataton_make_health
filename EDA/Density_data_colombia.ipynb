# %%
import pandas as pd

# %%
df = pd.read_csv('./Densidad_poblacional.csv', sep=";" )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121 entries, 0 to 1120
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Municipality code  1121 non-null   int64
#  1   Densidad2007       1121 non-null   float64
#  2   Densidad2008       1121 non-null   float64
#  3   Densidad2009       1121 non-null   float64
#  4   Densidad2010       1121 non-null   float64
#  5   Densidad2011       1121 non-null   float64
#  6   Densidad2012       1121 non-null   float64
#  7   Densidad2013       1121 non-null   float64
#  8   Densidad2014       1121 non-null   float64
#  9   Densidad2015       1121 non-null   float64
#  10  Densidad2016       1121 non-null   float64
#  11  Densidad2017       1121 non-null   float64
#  12  Densidad2018       1121 non-null   float64
#  13  Densidad2019       1121 non-null   float64
# dtypes: float64(13), int64(1)
# memory usage: 122.7 KB

# %%
df
# Out:
#       Municipality code  Densidad2007  Densidad2008  Densidad2009  \
# 0                 11001        3868.4        3908.2        3945.6
# 1                  5001        1288.0        1301.2        1313.5
# 2                 76001        1194.3        1197.8        1201.7
# 3                  8001         657.0         664.2         671.1
# 4                 13001         507.7         512.1         516.2
# ...                 ...           ...           ...           ...
# 1116              94885           0.1           0.1           0.1
# 1117              94886           0.1           0.1           0.1
# 1118              23815           0.0          23.2          23.7
# 1119              13490           0.0           2.2           2.2
# 1120              23682           0.0           4.4           4.5
#
#       Densidad2010  Densidad2011  Densidad2012  Densidad2013  Densidad2014  \
# 0           3980.7        4010.9        4035.1        4054.8        4071.4
# ...

# %%
density_data = df.melt(id_vars=["Municipality code"], 
        var_name="Date", 
        value_name="density")
density_data
# Out:
#        Municipality code          Date  density
# 0                  11001  Densidad2007   3868.4
# 1                   5001  Densidad2007   1288.0
# 2                  76001  Densidad2007   1194.3
# 3                   8001  Densidad2007    657.0
# 4                  13001  Densidad2007    507.7
# ...                  ...           ...      ...
# 14568              94885  Densidad2019      0.2
# 14569              94886  Densidad2019      0.5
# 14570              23815  Densidad2019     30.3
# 14571              13490  Densidad2019      5.4
# 14572              23682  Densidad2019      7.7
#
# [14573 rows x 3 columns]

# %%
density_data["year"] = density_data["Date"].apply(lambda x: int(x[-4:]))

# %%
density_data
# Out:
#        Municipality code          Date  density  year
# 0                  11001  Densidad2007   3868.4  2007
# 1                   5001  Densidad2007   1288.0  2007
# 2                  76001  Densidad2007   1194.3  2007
# 3                   8001  Densidad2007    657.0  2007
# 4                  13001  Densidad2007    507.7  2007
# ...                  ...           ...      ...   ...
# 14568              94885  Densidad2019      0.2  2019
# 14569              94886  Densidad2019      0.5  2019
# 14570              23815  Densidad2019     30.3  2019
# 14571              13490  Densidad2019      5.4  2019
# 14572              23682  Densidad2019      7.7  2019
#
# [14573 rows x 4 columns]

# %%
df.to_csv('density.csv',sep = ';', index=False)

# %%
completadf = pd.read_csv('./Densidad_poblacional.csv', sep=";" )

# %%
data_colombia_completa_2.csv
